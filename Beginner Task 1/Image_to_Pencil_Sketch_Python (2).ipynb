# %% [markdown]
# ***LGMVIP :***
# **Beginner Task-1 Image to Pencil Sketch with Python**

# %% [markdown]
# **By-Shaurya Srivastava**

# %% [markdown]
#  **Import cv2**

# %%
import cv2
from google.colab.patches import cv2_imshow

# %% [markdown]
# **Read Image**

# %%
image = cv2.imread("LGM.jpg")

# %% [markdown]
#  **Resize the image**

# %%
image=cv2.resize(image,(500,500))
cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=RGB size=500x500 at 0x7F8E5269E710>

# %% [markdown]
# **Image to Greyscale**

# %%
gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
cv2_imshow(gray_image)
# Out:
# <PIL.Image.Image image mode=L size=500x500 at 0x7F8E5269FAD0>

# %% [markdown]
# **Invert Greyscale Image**

# %%
inverted_image = 255 - gray_image
cv2_imshow( inverted_image)
# Out:
# <PIL.Image.Image image mode=L size=500x500 at 0x7F8E526AABD0>

# %% [markdown]
# **Convert into blur Image**

# %%
blurred = cv2.GaussianBlur(inverted_image, (21, 21), 0)
cv2_imshow(blurred)
# Out:
# <PIL.Image.Image image mode=L size=500x500 at 0x7F8E5269E350>

# %% [markdown]
# **Image to Pencil Sketch**

# %%
inverted_blurred = 255 - blurred
pencil_img = cv2.divide(gray_image, inverted_blurred, scale=256.0)
cv2_imshow(pencil_img)
# Out:
# <PIL.Image.Image image mode=L size=500x500 at 0x7F8E5269EA10>
